# %%
# This is the file for the 2025 OSU Spring Analytics Challenge
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
team_data = pd.read_csv("/content/drive/MyDrive/OSUHackathon2025_TeamGameData.csv")

playoff_teams = team_data[team_data['WasCFPTeam'] == 1]
playoff_teams_unique = playoff_teams.drop_duplicates(subset=['GameId'])

playoff_teams_IDFactors = playoff_teams_unique[['Season', "GameId", "Team",
                                                "OppTeam", "Conference",
                                                "WasCFPTeam", "Score",
                                                "OppScore"]]
print(playoff_teams_IDFactors)
# Out:
#        Season  GameId        Team              OppTeam Conference  WasCFPTeam  \
# 25       2018    2875     Alabama           Louisville        SEC           1
# 29       2018    2901     Alabama       Arkansas State        SEC           1
# 33       2018    3006     Alabama             Ole Miss        SEC           1
# 37       2018    3059     Alabama            Texas A&M        SEC           1
# 41       2018    3103     Alabama  Louisiana Lafayette        SEC           1
# ...       ...     ...         ...                  ...        ...         ...
# 11941    2024    8604  Washington              Indiana      BIG10           1
# 11942    2024    8625  Washington                  USC      BIG10           1
# 11944    2024    8724  Washington                 UCLA      BIG10           1
# 11945    2024    8896  Washington               Oregon      BIG10           1
# 11946    2024    8960  Washington           Louisville      BIG10           1
#
#        Score  OppScore
# 25        51        14
# 29        57         7
# 33        62         7
# 37        45        23
# 41        56        14
# ...      ...       ...
# 11941     17        31
# 11942     26        21
# 11944     31        19
# 11945     21        49
# 11946     34        35
#
# [961 rows x 8 columns]

# %%
playoff_teams_IDFactors
# Out:
#        Season  GameId        Team              OppTeam Conference  WasCFPTeam  \
# 25       2018    2875     Alabama           Louisville        SEC           1
# 29       2018    2901     Alabama       Arkansas State        SEC           1
# 33       2018    3006     Alabama             Ole Miss        SEC           1
# 37       2018    3059     Alabama            Texas A&M        SEC           1
# 41       2018    3103     Alabama  Louisiana Lafayette        SEC           1
# ...       ...     ...         ...                  ...        ...         ...
# 11941    2024    8604  Washington              Indiana      BIG10           1
# 11942    2024    8625  Washington                  USC      BIG10           1
# 11944    2024    8724  Washington                 UCLA      BIG10           1
# 11945    2024    8896  Washington               Oregon      BIG10           1
# 11946    2024    8960  Washington           Louisville      BIG10           1
#
#        Score  OppScore
# 25        51        14
# 29        57         7
# 33        62         7
# 37        45        23
# 41        56        14
# ...      ...       ...
# 11941     17        31
# 11942     26        21
# 11944     31        19
# 11945     21        49
# 11946     34        35
#
# [961 rows x 8 columns]
